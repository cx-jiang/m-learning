# %% [markdown]
# ![%E6%97%A0%E6%A0%87%E9%A2%98%E7%94%B5%E5%AD%90%E8%A1%A8%E6%A0%BC.png](attachment:%E6%97%A0%E6%A0%87%E9%A2%98%E7%94%B5%E5%AD%90%E8%A1%A8%E6%A0%BC.png)

# %% [markdown]
# ### W代表权重，O代表每一层的输出，本次推导不考虑偏置b

# %% [markdown]
# ### 误差E对于系数W45的偏导数

# %% [markdown]
# $
# 1.E = \frac{1}{2}(O_5 - T_5)^2
# $
#
# $
# 2.O_5 = \sigma(X_5)
# $
#
# $
# 3.X_5 = W_{35} \cdot O_3 + W_{45} \cdot O_4
# $
#
# $
# \begin{align}
# \frac{\partial{E}}{\partial{W_{45}}} &= \frac{\partial{E}}{\partial{O_5}} \cdot \frac{\partial{O_5}}{\partial{X_5}} \cdot \frac{\partial{X_5}}{\partial{W_{45}}}\\
# &= (O_5 - T_5) O_5(1 - O_5) O_4\\
# &= (O_5 - T_5) \sigma{(X_5)}(1 - \sigma{(X_5)}) O_4
# \end{align}
# $

# %% [markdown]
# ### 误差E对于系数W23的偏导数

# %% [markdown]
# $
# 1.E = \frac{1}{2}(O_5 - T_5)^2
# $
#
# $
# 2.O_5 = \sigma(X_5)
# $
#
# $
# 3.X_5 = W_{35} \cdot O_3 + W_{45} \cdot O_4
# $
#
# $
# 4.O_3 = \sigma(X_3)
# $
#
#
# $
# 5.X_3 = W_{13} \cdot X_1 + W_{23} \cdot X_2
# $
#
# $
# \begin{align}
# \frac{\partial{E}}{\partial{W_{23}}} &= \frac{\partial{E}}{\partial{O_5}} \cdot \frac{\partial{O_5}}{\partial{X_5}} \cdot \frac{\partial{X_5}}{\partial{O_3}} \cdot \frac{\partial{O_3}}{\partial{X_3}} \cdot \frac{\partial{X_3}}{\partial{W_{23}}}\\
# &= (O_5 - T_5) O_5(1 - O_5) W_{35} O_3(1 - O_3) X_2\\
# &= (O_5 - T_5) \sigma{(X_5)}(1 - \sigma{(X_5)}) W_{35} \sigma{(X_3)}(1 - \sigma{(X_3)}) X_2
# \end{align}
# $

# %% [markdown]
# ### 误差E对于系数W24的偏导数

# %% [markdown]
# $
# 1.E = \frac{1}{2}(O_5 - T_5)^2
# $
#
# $
# 2.O_5 = \sigma(X_5)
# $
#
# $
# 3.X_5 = W_{35} \cdot O_3 + W_{45} \cdot O_4
# $
#
# $
# 4.O_4 = \sigma(X_4)
# $
#
#
# $
# 5.X_3 = W_{14} \cdot X_1 + W_{24} \cdot X_2
# $
#
# $
# \begin{align}
# \frac{\partial{E}}{\partial{W_{24}}} &= \frac{\partial{E}}{\partial{O_5}} \cdot \frac{\partial{O_5}}{\partial{X_5}} \cdot \frac{\partial{X_5}}{\partial{O_4}} \cdot \frac{\partial{O_4}}{\partial{X_4}} \cdot \frac{\partial{X_4}}{\partial{W_{24}}}\\
# &= (O_5 - T_5) O_5(1 - O_5) W_{45} O_3(1 - O_4) X_2\\
# &= (O_5 - T_5) \sigma{(X_5)}(1 - \sigma{(X_5)}) W_{45} \sigma{(X_4)}(1 - \sigma{(X_4)}) X_2
# \end{align}
# $
